# %% [markdown]
# # Modelos: Comparativas

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../lib')

import numpy as np
import pandas as pd

import model as ml
import data.plot as pl
# Out:
# <Figure size 432x288 with 0 Axes>

# %% [markdown]
# ## Setup

# %%
PATH = '../metrics'

# %% [markdown]
# ## Comparativa

# %%
summary = ml.ValidatorSummary.load_and_join([
    f'{PATH}/knn', 
    f'{PATH}/gmf', 
    f'{PATH}/biased_gmf', 
    f'{PATH}/nnmf', 
    f'{PATH}/deep_fm'
])

# %%
summary.show()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sample</th>
#       <th>RMSE</th>
#       <th>mAP@5(4,5)</th>
#       <th>MeanUserF1Score@5(4,5)</th>
#       <th>Precision@5(4,5)</th>
#       <th>Recall@5(4,5)</th>
#       <th>mAP@5(3,5)</th>
#       <th>MeanUserF1Score@5(3,5)</th>
#       <th>Precision@5(3,5)</th>
#       <th>Recall@5(3,5)</th>
#     </tr>
#     <tr>
#       <th>predictor</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>BiasedGMF</th>
#       <td>249.5</td>
#       <td>0.967624</td>
#       <td>0.412080</td>
#       <td>0.675350</td>
#       <td>0.675268</td>
#       <td>0.675019</td>
#       <td>0.464471</td>
#       <td>0.809239</td>
#       <td>0.808525</td>
#       <td>0.809041</td>
#     </tr>
#     <tr>
#       <th>GMF</th>
#       <td>249.5</td>
#       <td>0.986547</td>
#       <td>0.410226</td>
#       <td>0.680484</td>
#       <td>0.679071</td>
#       <td>0.679260</td>
#       <td>0.464177</td>
#       <td>0.805252</td>
#       <td>0.806075</td>
#       <td>0.805774</td>
#     </tr>
#     <tr>
#       <th>KNNUserBasedPredictor</th>
#       <td>99.5</td>
#       <td>1.493595</td>
#       <td>0.405644</td>
#       <td>0.609814</td>
#       <td>0.608780</td>
#       <td>0.609726</td>
#       <td>0.462532</td>
#       <td>0.733553</td>
#       <td>0.734211</td>
#       <td>0.733665</td>
#     </tr>
#     <tr>
#       <th>DeepFM</th>
#       <td>249.5</td>
#       <td>1.060771</td>
#       <td>0.400027</td>
#       <td>0.620186</td>
#       <td>0.620007</td>
#       <td>0.619003</td>
#       <td>0.458980</td>
#       <td>0.808098</td>
#       <td>0.808746</td>
#       <td>0.809195</td>
#     </tr>
#     <tr>
#       <th>NNMF</th>
#       <td>249.5</td>
#       <td>0.976195</td>
#       <td>0.398433</td>
#       <td>0.631042</td>
#       <td>0.631310</td>
#       <td>0.631646</td>
#       <td>0.459156</td>
#       <td>0.817292</td>
#       <td>0.817499</td>
#       <td>0.816833</td>
#     </tr>
#     <tr>
#       <th>Ensemple[KNNUserBasedPredictor, KNNItemBasedPredictor]</th>
#       <td>99.5</td>
#       <td>1.440606</td>
#       <td>0.397417</td>
#       <td>0.638093</td>
#       <td>0.637438</td>
#       <td>0.637978</td>
#       <td>0.459241</td>
#       <td>0.649969</td>
#       <td>0.651039</td>
#       <td>0.650548</td>
#     </tr>
#     <tr>
#       <th>KNNItemBasedPredictor</th>
#       <td>99.5</td>
#       <td>1.802944</td>
#       <td>0.383683</td>
#       <td>0.617377</td>
#       <td>0.617542</td>
#       <td>0.617251</td>
#       <td>0.452825</td>
#       <td>0.670432</td>
#       <td>0.670516</td>
#       <td>0.671687</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from IPython.display import Latex
Latex(summary.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrrr}
#  & sample & RMSE & mAP@5(4,5) & MeanUserF1Score@5(4,5) & Precision@5(4,5) & Recall@5(4,5) & mAP@5(3,5) & MeanUserF1Score@5(3,5) & Precision@5(3,5) & Recall@5(3,5) \\
# predictor &  &  &  &  &  &  &  &  &  &  \\
# BiasedGMF & 249.500000 & 0.967624 & 0.412080 & 0.675350 & 0.675268 & 0.675019 & 0.464471 & 0.809239 & 0.808525 & 0.809041 \\
# GMF & 249.500000 & 0.986547 & 0.410226 & 0.680484 & 0.679071 & 0.679260 & 0.464177 & 0.805252 & 0.806075 & 0.805774 \\
# KNNUserBasedPredictor & 99.500000 & 1.493595 & 0.405644 & 0.609814 & 0.608780 & 0.609726 & 0.462532 & 0.733553 & 0.734211 & 0.733665 \\
# DeepFM & 249.500000 & 1.060771 & 0.400027 & 0.620186 & 0.620007 & 0.619003 & 0.458980 & 0.808098 & 0.808746 & 0.809195 \\
# NNMF & 249.500000 & 0.976195 & 0.398433 & 0.631042 & 0.631310 & 0.631646 & 0.459156 & 0.817292 & 0.817499 & 0.816833 \\
# Ensemple[KNNUserBasedPredictor, KNNItemBasedPredictor] & 99.500000 & 1.440606 & 0.397417 & 0.638093 & 0.637438 & 0.637978 & 0.459241 & 0.649969 & 0.651039 & 0.650548 \\
# KNNItemBasedPredictor & 99.500000 & 1.802944 & 0.383683 & 0.617377 & 0.617542 & 0.617251 & 0.452825 & 0.670432 & 0.670516 & 0.671687 \\
# \end{tabular}

# %%
summary.plot(bins=12)
# Out:
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 1 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
# <Figure size 1440x360 with 2 Axes>
