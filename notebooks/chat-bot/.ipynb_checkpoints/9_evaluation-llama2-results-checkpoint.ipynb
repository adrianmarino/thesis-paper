# %% [markdown]
# # Recommendation Chatbot API: llama2 ensemble evaluation Results

# %%
# %%capture output
# %load_ext autoreload
# %autoreload 2

# %%
import sys

BASE_PATH         = '../..'
API_PATH          = f'{BASE_PATH}/chat-bot-api'
LIB_PATH          = f'{BASE_PATH}/lib'
METRICS_PATH      = f'{BASE_PATH}/metrics'

sys.path.append(LIB_PATH)
sys.path.append(API_PATH)

# %%
import logging
import pytorch_common.util as pu
from models import EvaluationState

# %% [markdown]
# ## Setup

# %%
def on_file(file_path, format='%(asctime)s - %(levelname)s - %(message)s'):
    handler = logging.FileHandler(file_path)
    handler.setFormatter(logging.Formatter(format))
    return handler

pu.LoggerBuilder() \
    .handler(on_file('./evaluation.log'))\
    .on_console() \
    .build()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <RootLogger root (INFO)>

# %%
EvaluationState.load(f'{METRICS_PATH}/llama2-evaluation-metrics.dt') \
    .sessions \
    .plotter \
    .plot(
        figsize=(18, 8),
        min_sessions_by_step=10,
        save_path=f'{METRICS_PATH}/llama2-evaluation-metrics'
    )
# Out:
# 2024-11-15 14:35:55,999 - INFO - Sessions: 134
# 2024-11-15 14:35:55,999 - INFO - Sessions: 134
# 2024-11-15 14:35:56,000 - INFO - Max Session Steps Reached: 25
# 2024-11-15 14:35:56,000 - INFO - Max Session Steps Reached: 25
# 2024-11-15 14:35:56,032 - INFO - Sessions count >= 30 rated items: 51
# 2024-11-15 14:35:56,032 - INFO - Sessions count >= 30 rated items: 51
# 2024-11-15 14:35:56,034 - INFO - Total Session Steps: 1419
# 2024-11-15 14:35:56,034 - INFO - Total Session Steps: 1419
# 2024-11-15 14:35:56,047 - INFO - Mean NDCG: 0.97
# 2024-11-15 14:35:56,047 - INFO - Mean NDCG: 0.97
# 2024-11-15 14:35:56,051 - INFO - Mean Average Precision: 0.55
# 2024-11-15 14:35:56,051 - INFO - Mean Average Precision: 0.55
# 2024-11-15 14:35:56,055 - INFO - Mean Reciprocal Rank: 0.92
# 2024-11-15 14:35:56,055 - INFO - Mean Reciprocal Rank: 0.92
# 2024-11-15 14:35:56,062 - INFO - Mean Recall: 0.58
# 2024-11-15 14:35:56,062 - INFO - Mean Recall: 0.58
# 2024-11-15 14:35:56,223 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-15 14:35:56,223 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-15 14:35:56,226 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-11-15 14:35:56,226 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1485x1040 with 1 Axes>
# /home/adrian/development/personal/maestria/thesis-paper/notebooks/chat-bot/../../lib/data/plot/diagram/smoothlineplot.py:54: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=axis_fontsize)
# /home/adrian/development/personal/maestria/thesis-paper/notebooks/chat-bot/../../lib/data/plot/diagram/smoothlineplot.py:54: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=axis_fontsize)
# /home/adrian/development/personal/maestria/thesis-paper/notebooks/chat-bot/../../lib/data/plot/diagram/smoothlineplot.py:54: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=axis_fontsize)
# /home/adrian/development/personal/maestria/thesis-paper/notebooks/chat-bot/../../lib/data/plot/diagram/smoothlineplot.py:54: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=axis_fontsize)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1800x800 with 1 Axes>
