# %% [markdown]
# # Recommender ChatBot: LLM Output Parser Tests

# %%
# %load_ext autoreload
# %autoreload 2

# %%
BASE_PATH             = '../..'
LIB_PATH              = f'{BASE_PATH}/lib'

# %%
import sys
sys.path.append(LIB_PATH)

import numpy as np
import pandas as pd

import util as ut

import recommender as rd
# Out:
# 2024-01-20 17:32:56.747082: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-20 17:32:57.156032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-20 17:32:57.516419: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
output = "Based on the user profile and seen movies, here are 5 candidate movies for Adrian to watch:\n\n1. The Legend of Mor'du (2012): This animated movie is set in the Scottish Highlands and follows the story of a grumpy dragon who must protect his hoard from a group of brave adventurers. With its 3D animation and exciting plot, this movie is sure to provide an enjoyable viewing experience for Adrian.\n2. Flatland: The Film (2007): This animated movie is based on the classic novella by Edwin A. Abbott and takes place in a two-dimensional world where humans are trapped inside a flat plane. As a 3D enthusiast, Adrian will surely appreciate the visually stunning animation of this film.\n3. Porco Rosso (1992): This animated movie is set in the 1930s and follows the story of a retired World War I fighter pilot who now runs a reconnaissance business in the Mediterranean. With its mix of action, adventure, and humor, this movie will likely appeal to Adrian's taste in movies.\n4. Emperor's New Groove, The (2000): This animated movie follows the story of a spoiled and selfish emperor who is turned into a llama as punishment for his behavior. With its witty humor and fun characters, this movie will likely entertain Adrian.\n5. Shark Tale (2004): This animated movie takes place in a world where fish can talk and tells the story of a fish named Oscar who pretends to be a great white shark to impress his peers. With its catchy music and humorous characters, this movie will likely provide an enjoyable viewing experience for Adrian."
print(output)
# Out:
# Based on the user profile and seen movies, here are 5 candidate movies for Adrian to watch:
#
# 1. The Legend of Mor'du (2012): This animated movie is set in the Scottish Highlands and follows the story of a
# grumpy dragon who must protect his hoard from a group of brave adventurers. With its 3D animation and exciting
# plot, this movie is sure to provide an enjoyable viewing experience for Adrian.
# 2. Flatland: The Film (2007): This animated movie is based on the classic novella by Edwin A. Abbott and takes
# place in a two-dimensional world where humans are trapped inside a flat plane. As a 3D enthusiast, Adrian will
# surely appreciate the visually stunning animation of this film.
# 3. Porco Rosso (1992): This animated movie is set in the 1930s and follows the story of a retired World War I
# fighter pilot who now runs a reconnaissance business in the Mediterranean. With its mix of action, adventure, and
# humor, this movie will likely appeal to Adrian's taste in movies.
# ...

# %%
print(rd.MovieRecommendationsOutputParser(5).parse(output))
# Out:
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': "The legend of mor'du",
#             'description': 'This animated movie is set in the scottish highlands and follows the story of a grumpy
# dragon who must protect his hoard from a group of brave adventurers. with its 3d animation and exciting plot, this
# movie is sure to provide an enjoyable viewing experience for adrian.',
#             'release': '2012'
#         },
#         {
#             'number': 2,
#             'title': 'Flatland: the film',
#             'description': 'This animated movie is based on the classic novella by edwin a. abbott and takes place
# in a two-dimensional world where humans are trapped inside a flat plane. as a 3d enthusiast, adrian will surely
# appreciate the visually stunning animation of this film.',
#             'release': '2007'
#         },
#         {
#             'number': 3,
#             'title': 'Porco rosso',
# ...

# %%
import re
idx=0
re.findall(f'\n{idx+1}.\s*(.*?)\n{idx+2}.\s*', output)
# Out:
# ["The Legend of Mor'du (2012): This animated movie is set in the Scottish Highlands and follows the story of a grumpy dragon who must protect his hoard from a group of brave adventurers. With its 3D animation and exciting plot, this movie is sure to provide an enjoyable viewing experience for Adrian."]

# %%
output = "Based on the user's profile and seen movies, here are 5 candidate movies that may be of interest:\n\n1. (2006) Flatland: The Film - This animated movie is based on the classic novella by Edwin A. Abbott and explores themes of social hierarchy and conformity.\n2. (2008) Wow! A Talking Fish! - This 3D animated movie follows the story of a young boy who befriends a talking fish and goes on a magical adventure.\n3. (2011) Meet the Robinsons - This movie is an entertaining and heartwarming tale about a young inventor and his quest to save the world from evil geniuses.\n4. (2016) Anastasia: The Movie - This animated feature is based on the classic Disney musical and tells the story of a young woman who discovers she is the long-lost princess of Russia.\n5. (2017) Emperor's New Groove, The: The Movie - This animated movie follows the hilarious adventures of a spoiled emperor who is turned into a llama and must learn to be humble."
print(output)
# Out:
# Based on the user's profile and seen movies, here are 5 candidate movies that may be of interest:
#
# 1. (2006) Flatland: The Film - This animated movie is based on the classic novella by Edwin A. Abbott and explores
# themes of social hierarchy and conformity.
# 2. (2008) Wow! A Talking Fish! - This 3D animated movie follows the story of a young boy who befriends a talking
# fish and goes on a magical adventure.
# 3. (2011) Meet the Robinsons - This movie is an entertaining and heartwarming tale about a young inventor and his
# quest to save the world from evil geniuses.
# 4. (2016) Anastasia: The Movie - This animated feature is based on the classic Disney musical and tells the story
# of a young woman who discovers she is the long-lost princess of Russia.
# 5. (2017) Emperor's New Groove, The: The Movie - This animated movie follows the hilarious adventures of a spoiled
# emperor who is turned into a llama and must learn to be humble.

# %%
print(rd.MovieRecommendationsOutputParser(5).parse(output))
# Out:
# ERROR:root:Error to parse line: "(2006) Flatland: The Film - This animated movie is based on the classic novella by Edwin A. Abbott and explores themes of social hierarchy and conformity."
# ERROR:root:Error to parse line: "(2008) Wow! A Talking Fish! - This 3D animated movie follows the story of a young boy who befriends a talking fish and goes on a magical adventure."
# ERROR:root:Error to parse line: "(2011) Meet the Robinsons - This movie is an entertaining and heartwarming tale about a young inventor and his quest to save the world from evil geniuses."
# ERROR:root:Error to parse line: "(2016) Anastasia: The Movie - This animated feature is based on the classic Disney musical and tells the story of a young woman who discovers she is the long-lost princess of Russia."
# ERROR:root:Error to parse line: " (2017) Emperor's New Groove, The: The Movie - This animated movie follows the hilarious adventures of a spoiled emperor who is turned into a llama and must learn to be humble"
# ...

# %%
output = """
Based on the user profile and the given list of movies, here are 15 candidate movies that fit the user's profile and preference for a 3D animated movie:

1. Pooh's Heffalump Halloween Movie (2005): This is a Hanna-Barbera 3D animation movie that the user has not seen yet, based on their preferred genres of love, comedy, and their interest in 3D movies.
2. Emperor's New Groove, The (1997): Although this isn't a newly released 3D animated movie, it's worth considering since the user studied engineering, making it an intellectual choice for them, and its rating is quite high.
3. Meet the Robinsons, A (2007): This Disney animated 3D movie suits the user's genre preferences in comedy and sci-fi and has a decent rating.
4. DuckTales: The Movie - Treasure of the Lost Lamp (1990): Despite not being in 3D originally, this classic animated film is considered a candidate due to its comic genre preference and having been remastered for 3D release.
5. Adventures of Prince Achmed, The (1926): A silent, hand-drawn, and restored 3D animation that fits the user's age range and openness to international movies with a love and adventure theme.
6. Inuyasha the Movie: The Castle Beyond the Looking Glass (2001): Although this movie isn't exclusively a children's film and features the thriller, suspense, and adventure genres preferred by the user.
7. Cube Zero (2004): A 3D animation short film with science fiction elements that aligns with the user's stated preferences in engineering studies, age group, and genre tastes.
8. Deep Sea 3D (2009): With its intriguing underwater environments and nature themes, this is a compelling option for a user interested in exploring new 3D movies, particularly ones centered around suspenseful encounters with marine creatures.
9. Jackass 3D (2010): Despite containing primarily comedic elements, the user's profile does mention a preference for comedy as well, making this 3D movie an interesting and relevant choice to consider.
10. Piranha 3DD (2012): With a rating of 2.0 on the list, this 3D movie presents an intriguing combination of genres – suspense, science fiction, thriller, and comedy, aligning with user's stated genre preferences.
11. Step Up 3D (2010): This dance-oriented film contains elements of both love and drama while offering a compelling storyline and high production values in 3D.
12. IMAX: Hubble 3D (2010): This visually stunning and informative documentary presents an excellent opportunity to experience something both educational and unique, as the user is known to be curious about space exploration.
13. Meet the Fockers (2004) - This film might seem like a stretch for being in 3D since it is primarily a live-action comedy, but considering its success, popularity, and high rating, it is an appealing option worth considering. However, this suggestion would only apply if the user does not have any strong disinterest towards comedies in 3D.
14. The Good Dinosaur (2015): A family-friendly animated 3D movie by Pixar Animation Studios with a compelling storyline and elements of adventure and suspense.
15. The Angry Birds Movie 2 (2019): A popular sequel to the original 3D animated film, which aligns with user's genre preferences in comedy and offers engaging game-inspired visuals and humor.
"""

print(output)
# Out:
# Based on the user profile and the given list of movies, here are 15 candidate movies that fit the user's profile
# and preference for a 3D animated movie:
#
# 1. Pooh's Heffalump Halloween Movie (2005): This is a Hanna-Barbera 3D animation movie that the user has not seen
# yet, based on their preferred genres of love, comedy, and their interest in 3D movies.
# 2. Emperor's New Groove, The (1997): Although this isn't a newly released 3D animated movie, it's worth considering
# since the user studied engineering, making it an intellectual choice for them, and its rating is quite high.
# 3. Meet the Robinsons, A (2007): This Disney animated 3D movie suits the user's genre preferences in comedy and
# sci-fi and has a decent rating.
# 4. DuckTales: The Movie - Treasure of the Lost Lamp (1990): Despite not being in 3D originally, this classic
# animated film is considered a candidate due to its comic genre preference and having been remastered for 3D
# release.
# ...

# %%
print(rd.MovieRecommendationsOutputParser(15).parse(output))
# Out:
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': "Pooh's heffalump halloween movie",
#             'description': 'This is a hanna-barbera 3d animation movie that the user has not seen yet, based on
# their preferred genres of love, comedy, and their interest in 3d movies.',
#             'release': '2005'
#         },
#         {
#             'number': 2,
#             'title': "Emperor's new groove, the",
#             'description': "Although this isn't a newly released 3d animated movie, it's worth considering since
# the user studied engineering, making it an intellectual choice for them, and its rating is quite high.",
#             'release': '1997'
#         },
#         {
#             'number': 3,
#             'title': 'Meet the robinsons, a',
#             'description': "This disney animated 3d movie suits the user's genre preferences in comedy and sci-fi
# and has a decent rating.",
#             'release': '2007'
#         },
# ...

# %%
output = "Based on your user profile and the available movies listed, here are 15 candidate movies that match your preferences as a 3D animated movie:\n\n1. Emperor's New Groove, The (1997): An animated fantasy-comedy about a young Inca king who is turned into a servant by his advisor.\n2. Meet the Robinsons, A (2007): A 3D animated adventure-family film about an orphan boy who invents a machine that travels through time and meets his future self and family.\n3. Pooh's Heffalump Halloween Movie (2015): An animated Halloween-themed movie where Pooh and Piglet help their friends find the perfect costumes for a spooky celebration.\n4. DuckTales: The Movie - Treasure of the Lost Lamp (1990): An animated adventure film featuring Scrooge McDuck's grandkids and their quest to retrieve a treasure with the help of Aladdin and Jasmine.\n5. Adventures of Prince Achmed, The (1926/1998): A restored 3D version of this classic silent-era German animated fairy tale.\n6. Piranha 3DD (2012): A 3D sequel to the horror-comedy \"Piranha\" with a story revolving around underwater prehistoric piranhas and a water park.\n7. Friday the 13th Part 3: 3D (1982): A 3D slasher horror movie, featuring Jason Voorhees continuing his reign of terror at Camp Crystal Lake.\n8. Walking With Dinosaurs (2013): A 3D family-adventure animated movie based on the popular children's book, about a young dinosaur and his adventures in a prehistoric world.\n9. Jaws 3-D (1983): A 3D sequel to the original thriller/horror \"Jaws\" film, following a new underwater adventure with a great white shark as its primary threat.\n10. The Nutcracker in 3D (2010): An adaptation of Tchaikovsky's famous ballet, featuring a magical storyline and breathtaking 3D visuals.\n11. Ali Baba Bunny (1978): A Looney Tunes animated special where Bugs Bunny plays the role of Aladdin from \"Aladdin and His Wonderful Lamp\" in an Arabian adventure.\n12. Enchanted Kingdom 3D (2014): A family-oriented fantasy film about a girl who is transported to an enchanted kingdom full of mythical creatures and wonders.\n13. Jackass 3D (2010): An extended 3D version of the MTV reality television series where performers participate in outrageous, dangerous, and often silly challenges.\n14. Deep Sea 3D (2008): A nature documentary showcasing various deep-sea creatures in stunning 3D visuals, providing an insight into their habitats and behaviors.\n15. IMAX: Hubble 3D (2010): An IMAX documentary that provides a breathtaking look at the Hubble Space Telescope, its history, and the vastness of space through stunning 3D visuals."

print(output)
# Out:
# Based on your user profile and the available movies listed, here are 15 candidate movies that match your
# preferences as a 3D animated movie:
#
# 1. Emperor's New Groove, The (1997): An animated fantasy-comedy about a young Inca king who is turned into a
# servant by his advisor.
# 2. Meet the Robinsons, A (2007): A 3D animated adventure-family film about an orphan boy who invents a machine that
# travels through time and meets his future self and family.
# 3. Pooh's Heffalump Halloween Movie (2015): An animated Halloween-themed movie where Pooh and Piglet help their
# friends find the perfect costumes for a spooky celebration.
# 4. DuckTales: The Movie - Treasure of the Lost Lamp (1990): An animated adventure film featuring Scrooge McDuck's
# grandkids and their quest to retrieve a treasure with the help of Aladdin and Jasmine.
# 5. Adventures of Prince Achmed, The (1926/1998): A restored 3D version of this classic silent-era German animated
# fairy tale.
# ...

# %%
print(rd.MovieRecommendationsOutputParser(15).parse(output))
# Out:
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': "Emperor's new groove, the",
#             'description': 'An animated fantasy-comedy about a young inca king who is turned into a servant by his
# advisor.',
#             'release': '1997'
#         },
#         {
#             'number': 2,
#             'title': 'Meet the robinsons, a',
#             'description': 'A 3d animated adventure-family film about an orphan boy who invents a machine that
# travels through time and meets his future self and family.',
#             'release': '2007'
#         },
#         {
#             'number': 3,
#             'title': "Pooh's heffalump halloween movie",
#             'description': 'An animated halloween-themed movie where pooh and piglet help their friends find the
# perfect costumes for a spooky celebration.',
#             'release': '2015'
#         },
#         {
#             'number': 4,
# ...

# %%
output = """
Based on your user profile and the available 3D animated movies in the candidate list, here are my recommendations:\n\n1. Pooh's Heffalump Halloween Movie (2005): A fun and heartwarming adventure where Winnie-the-Pooh and his friends embark on a journey to find the perfect pumpkin for their Halloween party.\n\n2. Meet the Robinsons, A (2007): An animated science fiction comedy-adventure about a boy named Lewis who invents a machine that sends him into the future to meet his future self and prevent a disaster.\n\n3. Despicable Me 3 (2017): The third installment in the popular animated series follows Gru as he forms an alliance with the legendary Kyunko Soldiers in order to battle Balthazar Bratt, a former child star turned supervillain.\n\n4. Emperor's New Groove, The (2000): This animated fantasy-comedy follows the story of Emperor Kuzco, who is turned into a llama by his advisor Yzma and must rely on the loyalty of his servant Kronk to regain his throne.\n\n5. DuckTales: The Movie - Treasure of the Lost Lamp (1990): Join Scrooge McDuck and his grand-nephews as they go on an adventure to find the legendary lamp of Djinn, guarded by the infamous sorceress Morgana LeFay.\n\n6. Adventures of Prince Achmed, The (1973): A classic hand-drawn animation film about the brave prince and his companions who embark on a journey to rescue Princess Peri banu from the evil clutches of the sorcerer Agraffel.\n\n7. IMAX: Hubble 3D (2010): This stunning IMAX documentary offers an in-depth look at the wonders of space exploration as we join astronauts onboard the Discovery Space Shuttle to repair and upgrade the Hubble Space Telescope.\n\n8. Meet the Robinsons: Summer of a Lifetime (2015): In this 3D animated short film, Lewis teams up with the time-traveling Wrigley Robinson for an action-packed adventure across multiple dimensions to save their alternate selves.\n\n9. Alvin and the Chipmunks: The Road Chip (2015): This computer-animated family comedy sees Alvin, Simon, and Theodore setting out on a road trip to meet their mentor, Dave Seville, at his cousin's wedding in Florida, while also trying to save him from a businessman who wants to exploit them.\n\n10. Spies in Disguise (2019): A 3D animated adventure comedy about a secret agent, Lance Sterling, and a scientist, Walter Beckett, who transforms him into a pigeon for the greater good while on a mission to stop a dangerous technology that could turn every pigeon into a bomb.\n\n11. Paw Patrol: The Movie (2021): In this 3D computer-animated adventure film, Ryder and his team of rescue pups embark on their greatest adventure yet as they join forces with an elusive caped wolf known as Mighty Pup to stop a mysterious creature that's terrorizing Adventure Bay.\n\nI hope these recommendations cater to your desire for a 3D animated movie, user! Let me know if you have any other preferences or criteria I might be able to incorporate into my suggestions. Happy watching! :)
"""

print(output)
# Out:
# Based on your user profile and the available 3D animated movies in the candidate list, here are my recommendations:
#
# 1. Pooh's Heffalump Halloween Movie (2005): A fun and heartwarming adventure where Winnie-the-Pooh and his friends
# embark on a journey to find the perfect pumpkin for their Halloween party.
#
# 2. Meet the Robinsons, A (2007): An animated science fiction comedy-adventure about a boy named Lewis who invents a
# machine that sends him into the future to meet his future self and prevent a disaster.
#
# 3. Despicable Me 3 (2017): The third installment in the popular animated series follows Gru as he forms an alliance
# with the legendary Kyunko Soldiers in order to battle Balthazar Bratt, a former child star turned supervillain.
#
# 4. Emperor's New Groove, The (2000): This animated fantasy-comedy follows the story of Emperor Kuzco, who is turned
# into a llama by his advisor Yzma and must rely on the loyalty of his servant Kronk to regain his throne.
#
# ...

# %%
print(rd.MovieRecommendationsOutputParser(15).parse(output))
# Out:
# ERROR:root:Error to parse 12 line. list index out of range
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': "Pooh's heffalump halloween movie",
#             'description': 'A fun and heartwarming adventure where winnie-the-pooh and his friends embark on a
# journey to find the perfect pumpkin for their halloween party.',
#             'release': '2005'
#         },
#         {
#             'number': 2,
#             'title': 'Meet the robinsons, a',
#             'description': 'An animated science fiction comedy-adventure about a boy named lewis who invents a
# machine that sends him into the future to meet his future self and prevent a disaster.',
#             'release': '2007'
#         },
#         {
#             'number': 3,
#             'title': 'Despicable me 3',
#             'description': 'The third installment in the popular animated series follows gru as he forms an
# ...

# %%
output = """
Based on the user profile and considering only the 3D animated movies from the list, here are the top 15 candidate movies:\n\n1. Pooh's Heffalump Halloween Movie (2005): This spooky animated movie follows the adventures of Winnie The Pooh and his friends as they discover the joy and wonder of Halloween in the Hundred Acre Wood.\n2. Adventures of Prince Achmed, The (1973): This is a classic fairy tale animation created by Lotte Reiniger. The story revolves around a brave prince who goes on an adventure to rescue his beloved bride-to-be from the evil clutches of the sorcerer.\n3. Emperor's New Groove, The (1998): This is a comedy-adventure movie about a selfish and ungrateful prince who is turned into a shepherd after an inadvertent betrayal by his advisor.\n4. Meet the Robinsons, A (2007): A sci-fi animated adventure movie where a young inventor named Lewis meets future versions of himself and goes on a thrilling journey to prevent his own miserable demise.\n5. Despicable Me 3 (2017): In this comedy animated sequel, Gru faces new challenges when he joins a team of super-secret spies to stop evil Balthazar Bratt from unleashing mischief and mayhem.\n6. DuckTales: The Movie - Treasure of the Lost Lamp (1990): This action-packed animated movie follows the adventures of Scrooge McDuck, who teams up with his nephews Dewey, Louie, Webby and Launchpad to recover a magical lamp.\n7. Piranha 3DD (2012): Although it's a horror-comedy, there is a brief 3D animated segment featuring prehistoric piranhas terrorizing unsuspecting visitors at a water park.\n8. Jackass 3D (2010): The entire movie is in 3D, although it is not strictly an animated movie. However, it includes animated interludes and graphic visual effects, so it's worth considering based on the user profile.\n9. Inuyasha the Movie: The Castle Beyond the Looking Glass (2001): This romantic fantasy animation follows Inuyasha as he embarks on a mission to retrieve the Jewel of Four Souls before it falls into the wrong hands.\n10. Deep Sea 3D (2008): An IMAX 3D documentary that explores and showcases the breathtaking wonders and mysterious depths of the deep ocean.\n11. The Nutcracker in 3D (2010): This is a dance adaptation of Tchaikovsky's famous ballet, brought to life with stunning 3D effects.\n12. Life, Animated (2016): Although it is not strictly an animation, this documentary employs animated scenes based on the protagonist's childhood connection to Disney films as he comes to terms with autism and communicates through these movies.\n13. Cube Zero (2004): This science fiction anthology features several segments, including one that is animated in 3D and explores the theme of trapped individuals attempting to solve complex puzzles to escape their confines.\n14. IMAX: Hubble 3D (2010): This space exploration documentary presents an immersive experience with breathtaking images of Earth, the Moon, and various celestial bodies captured by the Hubble Space Telescope in stunning 3D detail.\n15. Emperor's New Groove: The Series - S2E6: \"The King's Challenge\" (2001): Although it is a TV show episode rather than a movie, this episode is noteworthy as it is an animated adaptation of the beloved \"Emperor's New Groove\" story. The 3D aspect can be experienced through 3DTV or specific devices, such as NVIDIA 3D Vision, to enhance visual effects
"""
print(output)
# Out:
# Based on the user profile and considering only the 3D animated movies from the list, here are the top 15 candidate
# movies:
#
# 1. Pooh's Heffalump Halloween Movie (2005): This spooky animated movie follows the adventures of Winnie The Pooh
# and his friends as they discover the joy and wonder of Halloween in the Hundred Acre Wood.
# 2. Adventures of Prince Achmed, The (1973): This is a classic fairy tale animation created by Lotte Reiniger. The
# story revolves around a brave prince who goes on an adventure to rescue his beloved bride-to-be from the evil
# clutches of the sorcerer.
# 3. Emperor's New Groove, The (1998): This is a comedy-adventure movie about a selfish and ungrateful prince who is
# turned into a shepherd after an inadvertent betrayal by his advisor.
# 4. Meet the Robinsons, A (2007): A sci-fi animated adventure movie where a young inventor named Lewis meets future
# versions of himself and goes on a thrilling journey to prevent his own miserable demise.
# ...

# %%
print(rd.MovieRecommendationsOutputParser(15).parse(output))
# Out:
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': "Pooh's heffalump halloween movie",
#             'description': 'This spooky animated movie follows the adventures of winnie the pooh and his friends as
# they discover the joy and wonder of halloween in the hundred acre wood.',
#             'release': '2005'
#         },
#         {
#             'number': 2,
#             'title': 'Adventures of prince achmed, the',
#             'description': 'This is a classic fairy tale animation created by lotte reiniger. the story revolves
# around a brave prince who goes on an adventure to rescue his beloved bride-to-be from the evil clutches of the
# sorcerer.',
#             'release': '1973'
#         },
#         {
#             'number': 3,
#             'title': "Emperor's new groove, the",
#             'description': 'This is a comedy-adventure movie about a selfish and ungrateful prince who is turned
# ...

# %%
output = " Based on the user profile provided and considering the seen movies as a reference to avoid recommending already watched films, here is a list of 15 candidate movies that might suit Adrian's taste. Note that some of these titles are not explicitly from the year 1980 but are within his preferred genres (thriller, suspense, science fiction, love, comedy) and were released close to or before 1980.\n\n1. Night of the Living Dead (1968): A classic horror film about a group of survivors who barricade themselves in a farmhouse as the living dead attack.\n2. Psycho (1960): Alfred Hitchcock's chilling thriller following the story of Norman Bates and his sinister mother.\n3. Invasion of the Body Snatchers (1956): A classic science fiction horror about an alien invasion taking over the small town of Santa Mira, California.\n4. Vertigo (1958): A classic suspense/thriller film by Alfred Hitchcock starring James Stewart as a former police detective juggling with his past and a new assignment.\n5. The Day the Earth Stood Still (1951): An influential science fiction thriller about an alien visitor who comes to Earth to warn humans of their self-destructive behavior.\n6. Rosemary's Baby (1968): A psychological horror following the story of a young woman, played by Mia Farrow, and her mysterious neighbors.\n7. The Texas Chainsaw Massacre (1974): A horror/thriller following a group of five friends on their way to visit their grandfather's grave, who get trapped by a crazed serial killer and his family.\n8. The Birds (1963): Another classic thriller from Alfred Hitchcock, where an immense number of birds descends upon Bodega Bay, California, and attacks people indiscriminately.\n9. A Nightmare on Elm Street (1984): A horror/thriller film introducing Freddy Krueger, a terrifying dream demon who stalks and kills children and teenagers in their dreams.\n10. Carrie (1976): Stephen King's psychological horror/thriller about a shy teenage girl who is bullied at school and subsequently discovers she has telekinetic powers.\n11. Halloween (1978): Another classic horror film about Michael Myers, a boy who butchers his older sister with a knife, then murders his stepfather years later. He escapes Smith's Grove Sanitarium and returns to Haddonfield to stalk and murder his younger sister.\n12. The Shining (1980): A psychological horror film by Stanley Kubrick based on Stephen King's novel about Jack Torrance, an off-season caretaker who becomes isolated with his family at the historic Overlook Hotel.\n13. Suspiria (1977): A classic Italian Giallo horror following the story of a young woman named Suzy Banning who enrolls in a prestigious German ballet school and soon uncovers dark secrets.\n14. Eyes Wide Shut (1996): While not directly from the 1980s, Stanley Kubrick's erotic thriller follows the story of Dr. Bill Harford who explores the hidden sexual desires of himself and his wife Alice. The movie features an atmospheric 19th-century setting.\n15. In the Mouth of Madness (1994): A horror/thriller film from Carpenter about an investigator named John Trent, who sets out to track down the missing writer Harlan Ellison. As he travels deeper into the woods, he comes across various terrifying supernatural phenomena based on the writer's stories.\n\nThese fifteen films are recommended for Adrian considering his profile and seen movies. If you prefer only those from 1980, please remove some of the listed films that were released earlier."

print(output)
# Out:
#  Based on the user profile provided and considering the seen movies as a reference to avoid recommending already
# watched films, here is a list of 15 candidate movies that might suit Adrian's taste. Note that some of these titles
# are not explicitly from the year 1980 but are within his preferred genres (thriller, suspense, science fiction,
# love, comedy) and were released close to or before 1980.
#
# 1. Night of the Living Dead (1968): A classic horror film about a group of survivors who barricade themselves in a
# farmhouse as the living dead attack.
# 2. Psycho (1960): Alfred Hitchcock's chilling thriller following the story of Norman Bates and his sinister mother.
# 3. Invasion of the Body Snatchers (1956): A classic science fiction horror about an alien invasion taking over the
# small town of Santa Mira, California.
# 4. Vertigo (1958): A classic suspense/thriller film by Alfred Hitchcock starring James Stewart as a former police
# ...

# %%
print(rd.MovieRecommendationsOutputParser(15).parse(output))
# Out:
# {
#     'recommendations': [
#         {
#             'number': 1,
#             'title': 'Night of the living dead',
#             'description': 'A classic horror film about a group of survivors who barricade themselves in a
# farmhouse as the living dead attack.',
#             'release': '1968'
#         },
#         {
#             'number': 2,
#             'title': 'Psycho',
#             'description': "Alfred hitchcock's chilling thriller following the story of norman bates and his
# sinister mother.",
#             'release': '1960'
#         },
#         {
#             'number': 3,
#             'title': 'Invasion of the body snatchers',
#             'description': 'A classic science fiction horror about an alien invasion taking over the small town of
# santa mira, california.',
#             'release': '1956'
#         },
#         {
#             'number': 4,
#             'title': 'Vertigo',
# ...
