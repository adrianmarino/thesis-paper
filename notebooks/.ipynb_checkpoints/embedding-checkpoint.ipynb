# %% [markdown]
# https://stackoverflow.com/questions/58568400/weighted-summation-of-embeddings-in-pytorch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')

import torch
import torch.nn as nn
from torch.nn import Conv1d, Embedding

from embedding import WeightedMean, EmbeddingWeightedMean

# %%
inputs = torch.LongTensor([
    [1, 2], 
    [3, 4],
    [5, 6]
])
inputs.size()
# Out:
# torch.Size([3, 2])

# %%
embedding = Embedding(6, 3)
embedding.weight
# Out:
# Parameter containing:
# tensor([[-0.8826,  1.8635,  1.8129],
#         [-1.2512, -1.1609,  0.6299],
#         [-0.8420, -0.2525,  0.8275],
#         [-1.6288, -0.2700,  0.9709],
#         [-0.2656,  0.3941, -0.9446],
#         [ 0.9416,  0.0629,  0.2305]], requires_grad=True)

# %%
conv = Conv1d(
    in_channels=, 
    out_channels=1, 
    kernel_size=1
)

# %%
import torch

batch_size=2

inputs = torch.randn(batch_size, 12, 256)
aggregation_layer = torch.nn.Conv1d(in_channels=12, out_channels=1, kernel_size=1)
weighted_sum = aggregation_layer(inputs)
weighted_sum.size()
# Out:
# torch.Size([2, 1, 256])

# %%
m = nn.Conv1d(3, 1, 1)
input = torch.randn(2, 3, 3)
input
# Out:
# tensor([[[-0.9616,  0.6723,  0.2668],
#          [-0.8554,  1.0097, -1.6980],
#          [ 0.2719,  0.6479, -0.3220]],
#
#         [[ 0.2073, -1.1840, -1.2173],
#          [-1.7794,  0.8119,  0.6815],
#          [ 1.7907,  0.1854, -1.7148]]])

# %%
output = m(input)

# %%
output.size()
# Out:
# torch.Size([2, 1, 3])

# %%
output
# Out:
# tensor([[[0.7102, 0.1214, 0.1205]],
#
#         [[0.0868, 0.9362, 0.9893]]], grad_fn=<SqueezeBackward1>)
